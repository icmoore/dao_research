# %%
import numpy as np
import pandas as pd
import datetime
from scipy.stats import norm
import matplotlib.pyplot as plt

# %%
def formatDates(arr,date_format="%Y-%m-%d %H:%M"):
    return [datetime.datetime.strptime(d, date_format) for d in arr]

def stripCharacter(arr,c,r=''):
    return [e.replace(c, r) for e in arr]

def str2Float(arr):
    return [float(e) for e in arr]

def getDate(t, strt_date):
    return datetime.datetime.strptime(strt_date, "%Y-%m-%d") + datetime.timedelta(days=t)

# %%
dai_bond = pd.read_csv('../resources/dai_bond.csv')
dai_bond = dai_bond.assign(evt_block_time = stripCharacter(dai_bond['evt_block_time'].values,'/','-'))
dai_bond = dai_bond.assign(evt_block_time = formatDates(dai_bond['evt_block_time'].values))
dai_bond = dai_bond.assign(initialBCV = str2Float(dai_bond['initialBCV'].values))
dai_bond = dai_bond.assign(newBCV = str2Float(dai_bond['newBCV'].values))
dai_bond.head(5)
# Out:
#        evt_block_time  initialBCV  newBCV  adjustment  addition  \
# 0 2021-12-07 07:52:00       754.0   742.0           0     False
# 1 2021-12-07 06:45:00       766.0   754.0          12     False
# 2 2021-12-07 04:40:00       778.0   766.0          12     False
# 3 2021-12-07 04:13:00       790.0   778.0          12     False
# 4 2021-12-07 03:40:00       802.0   790.0          12     False
#
#                                          evt_tx_hash  \
# 0  \xb93b803a72ef686788cb77d8ea2a26f5a7f034ad66bd...
# 1  \x6f96b42373b108b148148591a436a44524d7b885fe78...
# 2  \x3f8b00c64747e543d7b67938eaecfb66d97867c6e299...
# 3  \x6738507a272079225c0bbcd610d788a612a4c42a3a3b...
# 4  \x71f2b19b562c78be979ff8fce41f01cb80e80ecd0b86...
#
#                              contract_address  evt_index  evt_block_number
# 0  \x575409f8d77c12b05fed8b455815f0e54797381c        282          13757383
# 1  \x575409f8d77c12b05fed8b455815f0e54797381c        509          13757090
# 2  \x575409f8d77c12b05fed8b455815f0e54797381c         56          13756539
# 3  \x575409f8d77c12b05fed8b455815f0e54797381c         28          13756399
# 4  \x575409f8d77c12b05fed8b455815f0e54797381c        396          13756264

# %%
frax_bond = pd.read_csv('../resources/frax_bond.csv')
frax_bond = frax_bond.assign(evt_block_time = stripCharacter(frax_bond['evt_block_time'].values,'/','-'))
frax_bond = frax_bond.assign(evt_block_time = formatDates(frax_bond['evt_block_time'].values))
frax_bond = frax_bond.assign(initialBCV = str2Float(frax_bond['initialBCV'].values))
frax_bond = frax_bond.assign(newBCV = str2Float(frax_bond['newBCV'].values))
frax_bond.head(5)
# Out:
#        evt_block_time  initialBCV   newBCV  adjustment  addition  \
# 0 2021-12-11 09:29:00     13595.0  13247.0         348     False
# 1 2021-12-09 18:14:00     13943.0  13595.0         348     False
# 2 2021-10-17 13:04:00     13732.0  13943.0           0      True
# 3 2021-10-17 03:08:00     13521.0  13732.0         211      True
# 4 2021-10-15 17:28:00     13310.0  13521.0         211      True
#
#                                          evt_tx_hash  \
# 0  \xe821063c258396407b1a2c76cd8c8bf852d8f7fc9e04...
# 1  \x96c710a7a65269a53ce169a59cd013fb4189c2165418...
# 2  \x7e2476eff84c6651de417802eecba1acca11cd388323...
# 3  \x533d1240aea49f580ad284961d38728e40d8fb0db639...
# 4  \xe2770b0bb49723f9d2cec17f14bccf4d44d5fd25eeb0...
#
#                              contract_address  evt_index  evt_block_number
# 0  \x8510c8c2b6891e04864fa196693d44e6b6ec2514         31          13783041
# 1  \x8510c8c2b6891e04864fa196693d44e6b6ec2514         15          13772555
# 2  \x8510c8c2b6891e04864fa196693d44e6b6ec2514         50          13435591
# 3  \x8510c8c2b6891e04864fa196693d44e6b6ec2514        269          13432958
# 4  \x8510c8c2b6891e04864fa196693d44e6b6ec2514        532          13423971

# %%
ohm_frax_bond = pd.read_csv('../resources/ohm_frax_bond.csv')
ohm_frax_bond = ohm_frax_bond.assign(evt_block_time = stripCharacter(ohm_frax_bond['evt_block_time'].values,'/','-'))
ohm_frax_bond = ohm_frax_bond.assign(evt_block_time = formatDates(ohm_frax_bond['evt_block_time'].values))
ohm_frax_bond = ohm_frax_bond.assign(initialBCV = str2Float(ohm_frax_bond['initialBCV'].values))
ohm_frax_bond = ohm_frax_bond.assign(newBCV = str2Float(ohm_frax_bond['newBCV'].values))
ohm_frax_bond.head(5)
# Out:
#        evt_block_time  initialBCV  newBCV  adjustment  addition  \
# 0 2021-12-11 04:39:00      9006.0  9065.0          59      True
# 1 2021-12-10 00:37:00      8947.0  9006.0          59      True
# 2 2021-12-08 21:09:00      8888.0  8947.0          59      True
# 3 2021-12-07 14:35:00      8829.0  8888.0          59      True
# 4 2021-12-06 12:55:00      8770.0  8829.0          59      True
#
#                                          evt_tx_hash  \
# 0  \x5b9c9354018344afaa1f5d6aa3991da14eb4c7565b38...
# 1  \xee56ed753171c01dca757c32238aa408996785934d08...
# 2  \xc1091dd305bbda48c1cf517bf8a72c96ef35cfaf9c4e...
# 3  \x572f67467aac2364d8c264d88de15059345bd6c8b034...
# 4  \x8f4e2857e1b839543c6788aba3b6bc481d69ab357b69...
#
#                              contract_address  evt_index  evt_block_number
# 0  \xc20cfff07076858a7e642e396180ec390e5a02f7        308          13781783
# 1  \xc20cfff07076858a7e642e396180ec390e5a02f7        135          13774226
# 2  \xc20cfff07076858a7e642e396180ec390e5a02f7        236          13767062
# 3  \xc20cfff07076858a7e642e396180ec390e5a02f7        229          13759090
# 4  \xc20cfff07076858a7e642e396180ec390e5a02f7         58          13752413

# %%
ohm_dai_bond = pd.read_csv('../resources/ohm_dai_bond.csv')
ohm_dai_bond = ohm_dai_bond.assign(evt_block_time = stripCharacter(ohm_dai_bond['evt_block_time'].values,'/','-'))
ohm_dai_bond = ohm_dai_bond.assign(evt_block_time = formatDates(ohm_dai_bond['evt_block_time'].values))
ohm_dai_bond = ohm_dai_bond.assign(initialBCV = str2Float(ohm_dai_bond['initialBCV'].values))
ohm_dai_bond = ohm_dai_bond.assign(newBCV = str2Float(ohm_dai_bond['newBCV'].values))
ohm_dai_bond.head(5)
# Out:
#        evt_block_time  initialBCV  newBCV  adjustment  addition  \
# 0 2021-11-23 04:24:00       204.0   207.0           3      True
# 1 2021-11-17 22:22:00       201.0   204.0           3      True
# 2 2021-11-17 17:30:00       198.0   201.0           3      True
# 3 2021-11-17 09:09:00       195.0   198.0           3      True
# 4 2021-11-16 18:06:00       192.0   195.0           3      True
#
#                                          evt_tx_hash  \
# 0  \x15ad11aa3d9ca8aebe840ebc0defd03bc374356ff6c1...
# 1  \xba4e414a996c68f2aa287c0d24bae04f03af423381e4...
# 2  \xfdcf10e8a1ce415a139ec028a356727f4226d7aba7cd...
# 3  \x7c9f6a8078c9ad2bf5781712b41623f385eb13dbcd8d...
# 4  \xd0626adf67b305fde04fd928a5f54c06ce991d166137...
#
#                              contract_address  evt_index  evt_block_number
# 0  \x956c43998316b6a2f21f89a1539f73fb5b78c151        130          13668713
# 1  \x956c43998316b6a2f21f89a1539f73fb5b78c151        188          13635602
# 2  \x956c43998316b6a2f21f89a1539f73fb5b78c151         12          13634304
# 3  \x956c43998316b6a2f21f89a1539f73fb5b78c151         21          13632051
# 4  \x956c43998316b6a2f21f89a1539f73fb5b78c151         61          13628082
